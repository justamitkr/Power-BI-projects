# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df_ama = pd.read_csv(r"C:\Users\Acer\Downloads\Amazon Sales Records (2).csv")

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_ama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df_ama['Order Date'] = pd.to_datetime(df_ama['Order Date'])
df_ama['Order Date'] = df_ama['Order Date'].dt.strftime('%d/%m/%Y')

# %%
df_ama['Ship Date'] = pd.to_datetime(df_ama['Ship Date'])
df_ama['Ship Date'] = df_ama['Ship Date'].dt.strftime('%d/%m/%Y')

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_ama['Day'] = pd.DatetimeIndex(df_ama['Order Date']).day_name()

##df_airport['day_of_week'] = df_airport['Date'].dt.day_name() --- if time & date both are given in the same column
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:327: UserWarning: Parsing '28/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dtarr = DatetimeArray._from_sequence_not_strict(
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:327: UserWarning: Parsing '22/08/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dtarr = DatetimeArray._from_sequence_not_strict(
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:327: UserWarning: Parsing '20/06/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   dtarr = DatetimeArray._from_sequence_not_strict(
# ...

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_year = df_ama['Order Date'].apply(lambda x: x[-4:])

# %%
df_ama = pd.concat([df_ama, df_year], axis=1)

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_ama.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit', 'Day',
#        'Order Date'],
#       dtype='object')

# %%
df_ama.columns = ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
       'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
       'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit', 'Day',
       'Year']

# %%
df_ama[['Region','Units Sold']].groupby(['Region'])['Units Sold'].sum().sort_values().plot.bar(x= 'Region' , y = 'Units Sold')
plt.rcParams['figure.figsize'] = (15,6)
plt.title('Unit sold regionwise',fontsize=25)
plt.ylabel('Average of units sold', fontsize=15) 
plt.xlabel('Region', fontsize=25)
plt.show()

## sum of the sales

# %%
sns.barplot(x='Region' , y='Units Sold', data=df_ama)

##mean
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Units Sold'>

# %%
df_ama[['Region','Units Sold']].groupby(['Region'])['Units Sold'].mean().sort_values().plot.bar(x= 'Region' , y = 'Units Sold')
plt.rcParams['figure.figsize'] = (15,6)
plt.title('Unit sold regionwise',fontsize=25)
plt.ylabel('Average of units sold', fontsize=15) 
plt.xlabel('Region', fontsize=25)
plt.show()

##mean

# %%
df_ama[['Country','Total Revenue']].groupby(['Country'])['Total Revenue'].sum().plot.bar(x= 'Country' , y = 'Total Revenue')
plt.rcParams['figure.figsize'] = (15,6)
plt.title('Unit sold regionwise',fontsize=25)
plt.ylabel('Average of units sold', fontsize=15) 
plt.xlabel('Country', fontsize=25)
plt.show()

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_ama[['Country','Total Revenue']].groupby(['Country'])['Total Revenue'].sum().plot.bar(x= 'Country' , y = 'Total Revenue')
plt.rcParams['figure.figsize'] = (15,6)
plt.title('Unit sold regionwise',fontsize=25)
plt.ylabel('Average of units sold', fontsize=15) 
plt.xlabel('Region', fontsize=25)
plt.show()

# %%
df_ama[['Item Type', 'Total Profit']].groupby(['Item Type'])['Total Profit'].sum().plot.bar(x='Item Type', y= 'Total Profit')
plt.rcParams['figure.figsize'] = (15,8)
plt.title('Item wise profit', fontsize = 20)
plt.ylabel('Profit', fontsize =12)
plt.xlabel('Items', fontsize=12)
plt.show()

# %%
df_ama[['Sales Channel', 'Total Revenue']].groupby(['Sales Channel'])['Total Revenue'].sum().plot.bar(x = 'Sales Channel', y='Total Revenue')
plt.rcParams['figure.figsize'] = (15,8)
plt.title('Sales channel wise revenue', fontsize = 20)
plt.ylabel('Revenue', fontsize =12)
plt.xlabel('Channel', fontsize=12)
plt.show()

# %%
df_ama[['Day', 'Units Sold']].groupby(['Day'])['Units Sold'].sum().plot.bar(x = 'Day', y='Units Sold')
plt.rcParams['figure.figsize'] = (15,8)
plt.title('Daywise sales', fontsize = 15)
plt.ylabel('Sales', fontsize=12)
plt.xlabel('daywise', fontsize = 12)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
df_ama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
#  14  Day             100 non-null    object
#  15  Year            100 non-null    object
# dtypes: float64(5), int64(2), object(9)
# ...

# %%
df_ama['Order Date'] = df_ama['Order Date'].astype('datetime64[ns]')
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/05/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/08/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/06/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/04/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# ...

# %%
df_ama['Ship Date'] = df_ama['Ship Date'].astype('datetime64[ns]')
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/06/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/09/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/02/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# C:\Users\Acer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/04/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# ...

# %%
df_ama['diff_days'] = (df_ama['Ship Date'] - df_ama['Order Date']) / np.timedelta64(1, 'D')

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df2 = len(df_ama[(df_ama['diff_days']<0)])
df2
# Out:
# 30

# %%
df_ama = df_ama.drop(['diff_days'], axis =1)

# %%
df_ama
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df_ama['Sales Channel'].value_counts().plot.pie(explode = [0.05,0.1], autopct = '%1.1f%%', startangle =180, shadow = True, figsize = (4,4))
plt.title('Channel wise', size = 15)
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.pairplot(df_ama, hue = None, kind = 'reg', plot_kws = {'line_kws':{'color' : 'red'}})

# %%
df_ama.corr()
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000   -0.222907   -0.190941  -0.213201      -0.314688
# Units Sold    -0.222907    1.000000   -0.070486  -0.092232       0.447784
# Unit Price    -0.190941   -0.070486    1.000000   0.987270       0.752360
# Unit Cost     -0.213201   -0.092232    0.987270   1.000000       0.715623
# Total Revenue -0.314688    0.447784    0.752360   0.715623       1.000000
# Total Cost    -0.328944    0.374746    0.787905   0.774895       0.983928
# Total Profit  -0.234638    0.564550    0.557365   0.467214       0.897327
#
#                Total Cost  Total Profit
# Order ID        -0.328944     -0.234638
# Units Sold       0.374746      0.564550
# Unit Price       0.787905      0.557365
# Unit Cost        0.774895      0.467214
# Total Revenue    0.983928      0.897327
# Total Cost       1.000000      0.804091
# Total Profit     0.804091      1.000000

# %%
plt.figure(figsize = (16,9))
sns.heatmap(df_ama.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df_ama.to_csv('df_ama_cleaned.csv', index= False)
